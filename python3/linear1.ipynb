# %%
import pandas as pd

# %%
family=pd.read_csv('family.csv')

# %%
family
# Out:
#   Unnamed: 0.1  Unnamed: 0 name  age  wt
# 0            I           0   tp   21  40
# 1           II           1   sp   19  40
# 2          III           2   sp   10  20
# 3           IV           3   np   40  60
# 4            V           4   mp   30  50

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df=family

# %%
df.head
# Out:
# <bound method NDFrame.head of   Unnamed: 0.1  Unnamed: 0 name  age  wt
# 0            I           0   tp   21  40
# 1           II           1   sp   19  40
# 2          III           2   sp   10  20
# 3           IV           3   np   40  60
# 4            V           4   mp   30  50>

# %%
df
# Out:
#   Unnamed: 0.1  Unnamed: 0 name  age  wt
# 0            I           0   tp   21  40
# 1           II           1   sp   19  40
# 2          III           2   sp   10  20
# 3           IV           3   np   40  60
# 4            V           4   mp   30  50

# %%
x=family
y=df.target
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11476\4233546773.py in ?()
#       1 x=family
# ----> 2 y=df.target
#
# c:\Users\user\anaconda3\envs\py312\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'target'
